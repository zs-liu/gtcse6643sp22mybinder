# %%
import Pkg; Pkg.add(["Plots"]);
import Logging; Logging.disable_logging(Logging.Info)

# %%
const STATIC_LECTURE = false;

# %%
using LinearAlgebra;
using Plots; plotlyjs(); default(l=5, size=(900,550), label=false);
using Printf;
using Polynomials;

BLAS.set_num_threads(1)

if STATIC_LECTURE
    default(fmt=:png)
end

prettyprint(a) = map(x -> @sprintf("%+.2f", x), v)

function imshow(x; kwargs...)
    return heatmap(x
        , aspect_ratio=:equal
        , framestyle=:none
        , yflip=true
        , c=:diverging_gwv_55_95_c39_n256
        ; kwargs...
    )
end
p = plot!([0,1],[0,1]);
# Out:
# WebIO._IJuliaInit()

# %% [markdown]
# ### Warmup

# %% [markdown]
# # Stability of Householder Triangularization & Back Substitution

# %% [markdown]
# ## Review

# %% [markdown]
# ### Backward Error Analysis
#
# Forward relative error ...
#
# $$
# \frac{\|\tilde{f}(x) - f(x)\|}{\|f(x)\|}
# \leq
# \frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}
# +
# \frac{\|f(\tilde{x}) - f(x)\|}{\|f(x)\|}
# $$

# %% [markdown]
# $$
# \leq
# \frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}
# +
# (\kappa(x) + o(1))\frac{\|\tilde{x} - x\|}{\|x\|}
# $$

# %% [markdown]
# $$
# \underbrace{\frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}}_{\substack{O(\epsilon_{\text{machine}}) \\ \text{if (backward) stable}}}
# +
# \underbrace{(\kappa(x) + o(1))}_{O(\kappa(x))}\underbrace{\frac{\|\tilde{x} - x\|}{\|x\|}}_{\substack{O(\epsilon_{\text{machine}}) \\ \text{if (backward) stable}}}
# = O(\kappa(x) \epsilon_{\text{machine}})
# $$

# %% [markdown]
# ... is bounded by the product of conditioning and backward relative error for stable algorithms

# %% [markdown]
# ### Review: forward and backward errors of Householder QR

# %%
n_samples = 100; m_min = 10; m_max = 50

conds = Float64[]; Q_errs = Float64[]
R_rel_errs = Float64[]; A_rel_errs = Float64[]
for i in 1:n_samples
    # random size, Q, and R
    m = rand(m_min:m_max)
    R = triu(randn(m, m)); Q = qr(randn(m, m)).Q
    # construct A
    A = Q * R
    # algorithm: Householder QR
    Q2, R2 = qr(A)
    # fix signs
    signs = diagm(sign.(diag(R)).*sign.(diag(R2)))
    Q2 = Q2 * signs; R2 = signs * R2
    # compute errors 
    Q_err = norm(Q2 - Q)
    R_rel_err = norm(R2 - R) / norm(R)
    A_rel_err = norm(A - Q2 * R2) / norm(A)
    push!(conds, cond(A))
    push!(Q_errs, Q_err)
    push!(R_rel_errs, R_rel_err)
    push!(A_rel_errs, A_rel_err)
end

# %%
q = plot(conds, Q_errs
    , st = :scatter
    , title = "||Q₂ - Q||"
)
r = plot(conds, R_rel_errs
    , st = :scatter
    , title = "||R₂ - R|| / ||R||"
)
a = plot(conds, A_rel_errs
    , st = :scatter
    , title = "||A - Q₂R₂|| / ||A||"
    , ylim = (1.e-17, 1.e0)
    , xlabel = "κ(A)"
)
plot(q, r, a, layout=(3,1)
    , scale = :log10

    , size = (600,600)
)
# Out:
#     <div id="83fc508c-8bb6-4555-bb28-e4c7cf27db74" style="width:600px;height:600px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('83fc508c-8bb6-4555-bb28-e4c7cf27db74', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             1.3146064026028822e15,
#             1.5859714099654755e8,
#             1.9261367228878584e9,
#             2.1656147759727348e13,
#             1.0489258384235275e8,
#             6.401897434872243e10,
#             6.975286197515843e9,
#             2.0406431205813824e10,
#             3427.3446435595697,
#             3.398607483093503e12,
#             2.176937035408944e15,
#             4.5729105049052596e8,
#             442.3192161897552,
#             4.077140393136329e10,
#             7.591620843622614e9,
#             2.3112199091528797e9,
#             7.70494772143266e11,
#             1002.8095992146156,
#             1.6007931264507366e10,
#             4.585623845471599e13,
#             1.4373266584429308e15,
#             3.6460220487454963e9,
#             1.997597513099469e13,
#             2.9222345358000458e10,
#             13977.548995278354,
#             1.354835263824582e11,
#             453392.39486397966,
#             1.8863105824616554e17,
#             1.3799783078839241e10,
#             886139.4760591093,
#             1.217286177958285e16,
#             1.4896249562077843e17,
#             6.938306648443977e11,
#             8.961813418731416e10,
#             390472.34827086487,
#             3.467135127077258e6,
#             6.430093256511809e6,
#             6.862230145453876e7,
#             3.1308030066687565e15,
#             17010.21583874185,
#             1.285254637389588e11,
#             3929.0793575365324,
#             4.834051570488592e9,
#             2.6618248975777622e14,
#             6.527802116686816e14,
#             1064.3926913474825,
#             2.088089216418641e9,
#             6.376977544487831e12,
#             2.3276410111895404e11,
#             2.1088052704010628e14,
#             2.2874297206227112e11,
#             3.466688146129404e17,
#             7367.737181863213,
#             3.904163621625552e16,
#             16045.35679283527,
#             1.88051344597502e10,
#             1.4214640402093143e11,
#             34080.66505277372,
#             4.115102520115409e9,
#             2.3432075104655495e8,
#             7.555337108106604e6,
#             2.7922037964469725e6,
#             336079.89685200265,
#             380066.42364061,
#             1.982035206867882e7,
#             3.7846827842496656e7,
#             2.8980630907075464e11,
#             3.8973817527540694e6,
#             1.0697529965913223e9,
#             7.935395758912754e8,
#             5.796500938881273e7,
#             4.5950290493818797e17,
#             248191.13831566923,
#             3.724365670453163e8,
#             373815.2364722676,
#             2.959237250561752e17,
#             301770.3375002643,
#             2.8078268196404296e8,
#             3.1859850325867645e11,
#             8.398787378574344e14,
#             951408.6656069958,
#             1.023872486384709e8,
#             5.919790990552096e14,
#             5.03287399133616e13,
#             4.0755309321110455e11,
#             1.5215356694937559e13,
#             9.029541290830688e12,
#             4.659095477180584e6,
#             7.539321605988698e14,
#             1.5112612523435154e6,
#             2.31720600907237e18,
#             115500.90405014499,
#             21276.40011252352,
#             2.251882936422181e12,
#             5.994305481562124e10,
#             11383.559535180093,
#             3.7124167203433574e17,
#             6.979480499917226e12,
#             2.7840648526296844e10,
#             119013.19312657983
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.0007554984496956651,
#             4.842542899553128e-10,
#             2.373406563149418e-8,
#             3.391691057734368e-5,
#             9.906978280355877e-11,
#             2.361863039278994e-7,
#             8.852560692265856e-8,
#             1.2000442251896948e-7,
#             2.9514778510822534e-14,
#             1.7605414555047295e-5,
#             0.012710669780460933,
#             5.017259413959713e-9,
#             1.5664117249501643e-14,
#             1.4711413954721751e-7,
#             1.604459402625388e-7,
#             1.5111480016834044e-10,
#             6.400382346137721e-6,
#             3.800066688388458e-14,
#             2.7569435688447025e-8,
#             0.0003220951564317933,
#             0.0024122298503859636,
#             3.2367611950095497e-8,
#             3.218649743961258e-5,
#             1.0804656215943148e-8,
#             1.8996479965915635e-13,
#             4.3636901034135044e-8,
#             1.997644983323596e-12,
#             0.6397634294744292,
#             2.4547918258503033e-8,
#             2.8422803687637893e-12,
#             0.09921686066684653,
#             0.04565516441541946,
#             1.9096380279884268e-6,
#             1.5061346909642828e-7,
#             1.942007496431526e-12,
#             1.4797737687717317e-11,
#             8.57571875772989e-11,
#             9.563867387566417e-10,
#             0.002102003432257622,
#             2.7940029674606952e-14,
#             1.0124578094386165e-6,
#             1.240814780258578e-14,
#             1.3569113115917078e-10,
#             0.0002044122690134803,
#             0.002227183524237802,
#             1.0113762966692158e-14,
#             3.7455569525035583e-10,
#             1.8643851789707725e-5,
#             5.210342244078215e-7,
#             0.0009007706029705644,
#             7.64319799965647e-7,
#             2.02602936996878,
#             8.292267411755899e-14,
#             2.861202975797317,
#             5.6622925059898593e-14,
#             1.1915743589009085e-7,
#             3.025151508163e-6,
#             5.062060325871263e-13,
#             2.4730143257145084e-8,
#             3.380761794270635e-9,
#             3.831924915382216e-13,
#             6.183726962330958e-11,
#             6.876338062592301e-13,
#             1.6615909753220541e-12,
#             6.610924693116101e-11,
#             1.3228845575836051e-10,
#             8.790511683921747e-8,
#             1.8579249459671047e-11,
#             1.2012648277986484e-8,
#             4.461353301144264e-9,
#             7.277029770266327e-11,
#             2.0012605595447295,
#             5.291234488581365e-13,
#             7.2253122717750586e-9,
#             2.2778165323298462e-12,
#             2.1516043041122797,
#             1.739368388816884e-12,
#             1.2741632098816111e-9,
#             7.04707173696337e-7,
#             0.0030628832652692334,
#             1.3894007997671688e-12,
#             3.999150348416211e-10,
#             0.0006616607113806186,
#             7.239655392669801e-5,
#             2.849311444412526e-6,
#             2.9527269076591856e-5,
#             4.651536535520316e-6,
#             1.8375729382831933e-10,
#             0.005920022921664848,
#             1.5866137140074169e-12,
#             0.048329743868053665,
#             1.7709460130554091e-12,
#             1.4089129891203778e-14,
#             5.126857603442224e-7,
#             6.053562033753334e-7,
#             3.0203547420827826e-14,
#             1.4414573765180676,
#             5.238498572682269e-6,
#             4.545841554266458e-8,
#             3.584913273636142e-13
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             1.3146064026028822e15,
#             1.5859714099654755e8,
#             1.9261367228878584e9,
#             2.1656147759727348e13,

# %% [markdown]
# - Small backward errors (stable), forward errors $\propto \kappa(A)$

# %% [markdown]
# ### T&B Theorem 16.1
#
# Let the QR factorization $A = QR$ of a matrix $A \in \mathbb{C}^{m \times n}$ be computed by Householder triangularization on a computer satisfying the floating point axioms, and let the computed $\tilde{Q}$ be
#
# $$
# \tilde{Q} = \tilde{Q}_1 \tilde{Q}_2 \dots \tilde{Q}_n,
# $$
#
# where $\tilde{Q}_k$ is the Householder reflector of the computed reflector $\tilde{v}_k$.  Then
#
# $$\tilde{Q}\tilde{R} = A + \delta A, \quad \frac{\|\delta A\|}{\|A\|} = O(\epsilon_{\text{machine}}), \quad \text{[backward stability]}$$
#
# for some $\delta A \in \mathbb{C}^{m \times n}$.

# %% [markdown]
# ### Details on $\tilde{Q}_k$
#
# - In Householder QR the solution is not a computed $Q$, it is the Householder reflectors $v_k$ that define
# $Q_k$:
#
# $$Q = Q_1 Q_2 \cdots Q_n.$$

# %% [markdown]
# - $\tilde{Q}_k$ is the _exactly unitary_ matrix for the computed vector $\tilde{v}_k$
# - so $\tilde{Q}$ is _exactly unitary_, even though $\tilde{Q} \neq Q$ (as demonstrated in the experiment)

# %% [markdown]
# ## Analyzing Solving $Ax = b$ with Householder QR
#
# > QR factorization is generally not an end itself, but a means to other ends such as solution of a system of equations [...]

# %% [markdown]
# > Is its backward stability enough to make it a satisfactory piece of a larger algorithm? [...] or do we need accuracy of $Q$ and $R$ individually?

# %% [markdown]
# ### Solving $Ax = b$ with Householder QR

# %%
function householder_solve(A, b)
    Q, R = qr(A) # Factor A by Householder triangularization
    y = Q' * b   # Compute Q* b by applying the reflectors in order
    x = R \ y    # Solve the triangular system R x = y by back substitution
    return x
end;

# %% [markdown]
# **Backward stability of steps (takes as given for now):**

# %% [markdown]
# 1. $\tilde{Q}, \tilde{R} \gets QR(A)$: just stated as T&B Theorem 16.1

# %% [markdown]
# 2. $\tilde y \gets \tilde{Q}^* b$: yes (**HW 3 Q 6**, roughly)
#
# $$(\tilde{Q} + \delta Q) \tilde y = b, \quad \|\delta Q\| = O(\epsilon_{\text{machine}})$$

# %% [markdown]
# 3. $\tilde x \gets \tilde{R}^{-1} \tilde y$: yes (coming up next),
#
# $$(\tilde R + \delta R) \tilde x = \tilde y, \quad \frac{\|\delta R\|}{\|\tilde R\|} = O(\epsilon_{\text{machine}}).$$

# %% [markdown]
# ### T&B Theorem 16.2.
#
# `householder_solve` is backward stable, satisfying
#
# $$
# (A + \Delta A) \tilde x = b, \quad \frac{\|\Delta A\|}{\|A\|} = O(\epsilon_{\text{machine}})
# $$
#
# for some $\Delta A \in \mathbb{C}^{m \times m}$.

# %% [markdown]
# $$
# \begin{aligned}
# A + \delta A &= \tilde Q \tilde R &\star\\
# (\tilde Q + \delta Q) \tilde y &= b &\clubsuit \\
# (\tilde R + \delta R) \tilde x &= \tilde y & \spadesuit
# \end{aligned}
# $$

# %% [markdown]
# _Proof._

# %% [markdown]
# Combine $\clubsuit$, $\spadesuit$:
#
# $$
# b = (\tilde Q + \delta Q)(\tilde R + \delta R) \tilde x = [\tilde Q \tilde R + (\delta Q) \tilde R + \tilde Q (\delta R) + (\delta Q)(\delta R)]\tilde x
# $$

# %% [markdown]
# Apply $\star$:
#
# $$
# b = [A + \underbrace{\delta A + (\delta Q) \tilde R + \tilde Q (\delta R) + (\delta Q)(\delta R)}_{\Delta A}]\tilde x
# $$

# %% [markdown]
# We want $\|\Delta A\| / \|A\| = O(\epsilon_{\text{machine}})$, will show each of the four terms is $O(\|A\|\epsilon_{\text{machine}})$

# %% [markdown]
# $$\frac{\|\delta A\|}{\|A\|} = O(\epsilon_{\text{machine}})\quad[\star]$$

# %% [markdown]
# $$
# \frac{\|(\delta Q) \tilde R\|}{\|A\|} \leq
# \|\delta Q\| \frac{\|\tilde R\|}{\|A\|} =
# \|\delta Q\| \frac{\|\tilde{Q}^*(A + \delta A)\|}{\|A\|}
# =
# \underbrace{\|\delta Q\|}_{O(\epsilon_{\text{machine}}) [\clubsuit]} \underbrace{\frac{\|A + \delta A\|}{\|A\|}}_{O(1)}
# = O(\epsilon_{\text{machine}})
# $$

# %% [markdown]
# $$
# \frac{\|\tilde{Q}(\delta R)\|}{\|A\|} =
# \frac{\|\delta R\|}{\|A\|} = \underbrace{\frac{\|\delta R\|}{\|\tilde R\|}}_{O(\epsilon_{\text{machine}}) [\spadesuit]}\frac{\|\tilde R\|}{\|A\|} =O(\epsilon_{\text{machine}})
# $$

# %% [markdown]
# $$\frac{\|(\delta Q)(\delta R)\|}{\|A\|} \leq
# \|(\delta Q)\|\frac{\|(\delta R)\|}{\|A\|} = O(\epsilon_{\text{machine}}^2)
# $$

# %% [markdown]
# ### Now applying our backward error analysis theorem

# %% [markdown]
# **T&B Theorem 16.3.** The computed solution $\tilde{x}$ of `householder_solve` satisfies
#
# $$\frac{\|\tilde x - x\|}{\|x\|} = O(\kappa(A) \epsilon_{\text{machine}}).$$

# %% [markdown]
# ## Stability of Back Substitution

# %% [markdown]
# ### Triangular Systems
#
# We wish to solve $Rx = b$,
#
# $$
# \begin{bmatrix}
# r_{11} & r_{12} & \cdots & r_{1m} \\
#        & r_{22} &        & \vdots \\
#        &        & \ddots & \vdots \\
#        &        &        & r_{mm}
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\ x_2 \\ \vdots \\ x_m
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1 \\ b_2 \\ \vdots \\ b_m
# \end{bmatrix}
# $$

# %% [markdown]
# Subproblem of:
#
# - Solving $Ax = b$ / least squares by QR
# - Solving $Ax = b$ by LU (Gaussian elimination)
# - Solving $Ax = b$ by Cholesky

# %%
function backsubstitution(R, b)
    m = length(b)
    x = copy(b)
    for j = m:-1:1
        x[j] /= R[j,j]
        for i = 1:j-1
            x[i] -= R[i,j] * x[j]
        end
    end
    return x
end;

# %%
function backsubstitution_vec(R, b)
    m = length(b)
    x = copy(b)
    for j = m:-1:1
        x[j] /= R[j,j]
        x[1:j-1] -= R[1:j-1,j] * x[j]
    end
    return x
end;

# %% [markdown]
# These two algorithms are floating-point identical.  They differ from backslash only in the order of subtractions:

# %%
m = 100;
R = qr(randn(m,m)).R

b = randn(m)
x_backslash = R \ b
x_backsub = backsubstitution(R, b)
x_backsubv = backsubstitution_vec(R, b)
display(norm(x_backslash - x_backsub) / norm(x_backslash))
display(norm(x_backslash - x_backsubv) / norm(x_backslash))
# Out:
# 4.2196633074932167e-16
# 4.2196633074932167e-16

# %% [markdown]
# ### T&B Theorem 17.1.
#
# Suppose $b = \mathrm{fl}(b)$ and $R = \mathrm{fl}(R)$.  `backsubstitution` is backward stable:
#
# $$(R + \delta R) \tilde x = b$$
#
# for some upper-triangular $\delta R$ with
#
# $$\frac{\|\delta R\|}{\|R\|} = O( \epsilon_{\text{machine}} ).$$
#
# Elementwise,
#
# $$
# \frac{|\delta r_{ij}|}{|r_{ij}|} \leq m \epsilon_{\text{machine}} + O(\epsilon^2).
# $$

# %% [markdown]
# ### Exercise
#
# What does this theorem imply about $\|\tilde x - x\| / \|x\|$?
#
# From T&B Theorem 15.1, we have:$$\frac{\|\tilde x - x\| }{ \|x\|}=\mathcal{O}(\kappa(R)\epsilon_m)$$

# %%
n_samples = 100; m_min = 10; m_max = 50

conds = Float64[]; 
x_rel_errs = Float64[]; b_rel_errs = Float64[]
for i in 1:n_samples
    # random size, R, and x
    m = rand(m_min:m_max)
    R = triu(rand(m,m))
    x = randn(m)
    b = R * x
    # construct b
    # algorithm: backsubstitution
    # compute errors 
    x2 = backsubstitution(R,b)
    x_rel_err = norm(x2 - x)/norm(x)
    b_rel_err = norm(b - R * x2)/norm(b)
    push!(conds, cond(R))
    push!(x_rel_errs, x_rel_err)
    push!(b_rel_errs, b_rel_err)
end

# %%
x = plot(conds, x_rel_errs
    , st = :scatter
    , title = "||x₂ - x|| / ||x||"
)
b = plot(conds, b_rel_errs
    , st = :scatter
    , title = "||b - R x₂|| / ||R||"
    , ylim = (1.e-17, 1.e0)
    , xlabel = "κ(A)"
)
plot(x, b, layout=(2,1)
    , scale = :log10
)
# Out:
#     <div id="c4ba6ca4-0fdf-418e-a4f2-f6f93e2f7714" style="width:900px;height:550px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('c4ba6ca4-0fdf-418e-a4f2-f6f93e2f7714', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             6.916710463821588e8,
#             3.4125607469744496e7,
#             13877.472466414536,
#             4.8099983875775856e8,
#             2.7599888835090797e7,
#             1665.554126336705,
#             2.696447038181972e8,
#             516208.74268856354,
#             64933.44651742527,
#             2.954913731960849e11,
#             18251.814282661584,
#             2.7478817207931128e9,
#             4.759111616317403e7,
#             4.712233766933458e7,
#             6.438245698096117e9,
#             48158.27619643655,
#             582239.390736821,
#             8.504577349003548e6,
#             4.461048727408103e11,
#             37909.78221836834,
#             4.9632631091529703e8,
#             3.634222042743002e6,
#             9.060997959350266e8,
#             4.926067848929026e7,
#             4.033496331919657e7,
#             5.3511131913798416e8,
#             5.036257705092632e16,
#             1.044713637414125e8,
#             22615.877169773245,
#             98.83933324096022,
#             1.1695073251900223e10,
#             4.252934389881776e9,
#             1.1219901421550053e8,
#             2.2826878002726332e13,
#             1.6761171446291812e7,
#             4.2170089010714626e8,
#             1.190799715490425e13,
#             1.7741108090291183e9,
#             3.576906196491722e11,
#             16984.403283319756,
#             4.1976736589600697e9,
#             4.90933307275277e12,
#             467076.0739048,
#             2.035006291109193e13,
#             864.3688274197249,
#             31109.744841042757,
#             6.186926087695163e8,
#             8.214768122944267e6,
#             9.472970499720595e8,
#             1.0516953487203753e9,
#             985221.3936086055,
#             678488.9472630562,
#             1.4659451046411445e7,
#             1.4818994480827479e7,
#             66849.06174939683,
#             37.02290063521771,
#             6.96603239661149e10,
#             2.294021051439876e7,
#             2.3460667999364233e11,
#             8.270586774743338e7,
#             5.635349363574062e6,
#             8.624635110565622e8,
#             4.181434603027186e6,
#             1.5416045862698781e9,
#             223042.28365281803,
#             3.50769126529803e10,
#             5.519122767709758e11,
#             2.846905920074152e7,
#             8.958887655329302e6,
#             1.2227696933775227e10,
#             2.114513336295742e6,
#             664201.8327565907,
#             3.488385408369693e11,
#             2.084485301453931e10,
#             6.128579171937986e6,
#             1.2110865502522367e6,
#             1.9319952017874181e9,
#             5.733795225292401e8,
#             1007.75956768051,
#             165935.323332959,
#             1.6244759832030866e9,
#             1.019227238593555e8,
#             300463.8141656244,
#             1542.6719413138358,
#             101981.07552280666,
#             65428.2380027639,
#             8.677511642736841e9,
#             2.1798920956649773e13,
#             1.327340567750546e8,
#             8.919816855470728e6,
#             1.046029110861355e10,
#             20446.292329422802,
#             1.346802317147428e7,
#             3.5294719212550275e7,
#             18100.198526846,
#             2.591235075939019e7,
#             3.237403363053969e6,
#             9.48927279098454e12,
#             3.027835619930137e10,
#             2.840590809376717e13
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             1.8513250100839966e-10,
#             5.0497761259085175e-11,
#             3.546495896105156e-14,
#             5.984657469295127e-11,
#             7.217916415662457e-11,
#             1.963938794607898e-15,
#             3.0976446244143706e-10,
#             8.044736675000821e-14,
#             1.3195318003377349e-13,
#             1.3951376863680451e-8,
#             6.566303150956422e-14,
#             1.7584156230272894e-10,
#             4.978122681295764e-11,
#             9.392800678499904e-12,
#             8.514935157350653e-11,
#             1.6163176611255e-13,
#             1.1941740640138786e-13,
#             1.4163889025806417e-11,
#             1.1297593598023034e-7,
#             2.411966292173735e-14,
#             3.7233400756680326e-12,
#             2.626007621146904e-12,
#             1.7915755700086325e-9,
#             4.274575093317233e-11,
#             3.3629082530765375e-11,
#             8.667993029081459e-11,
#             0.12548700910467567,
#             2.1882711265811117e-11,
#             1.0581545032522633e-15,
#             7.808036176446988e-16,
#             4.543558751916163e-9,
#             6.8798808814531055e-9,
#             9.868851749471466e-11,
#             6.009707505527474e-6,
#             1.782575967840304e-11,
#             6.329964539438833e-10,
#             2.583030663074325e-5,
#             9.865672951437351e-10,
#             2.669716425137023e-7,
#             5.126186827715841e-14,
#             2.468358851516248e-10,
#             7.348620579257656e-7,
#             2.6485592266013797e-14,
#             2.775590427123313e-6,
#             1.6016163249851434e-15,
#             9.48917423223098e-14,
#             8.461323652579172e-11,
#             1.4960082450054862e-11,
#             8.223296770920441e-10,
#             2.285781407581203e-10,
#             9.71082122557731e-13,
#             1.3663627027466395e-12,
#             1.3331189468203036e-11,
#             1.713073094794062e-12,
#             4.0176878475531733e-14,
#             2.1351566311099156e-16,
#             1.1659465995032708e-8,
#             4.3462555919896075e-11,
#             4.460331652005729e-7,
#             1.0963498036458662e-11,
#             3.0892738006904603e-12,
#             5.710379998357328e-10,
#             4.895593564141841e-13,
#             2.3105483013342524e-10,
#             2.546276065823721e-13,
#             6.584338353519168e-9,
#             3.5256256065562627e-9,
#             5.3522449963591685e-12,
#             1.2206643583316098e-11,
#             3.2745354633318936e-9,
#             3.575640569097597e-12,
#             3.819792615338763e-12,
#             1.4911229438516219e-7,
#             1.1315774247761709e-8,
#             2.0323656273255594e-12,
#             3.685802300670634e-12,
#             8.467667603106925e-12,
#             7.18039033927754e-11,
#             1.3261650765596195e-15,
#             2.955404623467775e-13,
#             1.3687084039642753e-9,
#             4.0816376948638273e-10,
#             7.081072558693814e-14,
#             1.9704511146757136e-14,
#             2.546174126444127e-14,
#             2.162719349773914e-13,
#             1.4978660236759139e-9,
#             2.3462512872092316e-5,
#             3.393660394628691e-11,
#             1.8967610827953733e-11,
#             7.278336530163618e-10,
#             2.0283996432656393e-15,
#             2.2442592843453022e-10,
#             5.0399028763345724e-11,
#             6.081760768442963e-16,
#             6.082406092164076e-12,
#             9.95842092786527e-13,
#             7.104519536741514e-6,
#             1.024664228399815e-9,
#             1.6189339830772585e-6
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             6.916710463821588e8,
#             3.4125607469744496e7,
#             13877.472466414536,
#             4.8099983875775856e8,
#             2.7599888

# %% [markdown]
# Remember we are trying to prove $(R + \delta R)\tilde x = b$: accumulate backward errors into $\tilde{R}$

# %% [markdown]
# ### A useful lemma (Higham)
#
# If $|\epsilon_i| \leq \epsilon_{\text{machine}}$ for each $i$ and $\rho_i = \pm 1$, then
#
# $$
# \prod_{i=1}^n (1 + \epsilon_i)^{\rho_i} = (1 + \theta_n), \quad |\theta_n| \leq \frac{n\epsilon_{\text{machine}}}{1 - n\epsilon_{\text{machine}}} =: \gamma_n = n \epsilon_{\text{machine}} + O(\epsilon_{\text{machine}}^2).
# $$
#
# We can treat $(1 + \epsilon_i)^{-1}$ and $(1 + \epsilon)$ the same!

# %% [markdown]
# If $\theta_n$ appears twice in the same expression, such as $x(1 + \theta_n) + y(1 + \theta_n)$, each one represents a different accumulated error.

# %% [markdown]
# ## $m = 1$

# %% [markdown]
# $$\tilde{x}_1 \gets b_1 \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$

# %% [markdown]
# By floating point axiom,
#
# $$\tilde x_1 = (b_1 / r_{11})(1 + \epsilon_1) = b_1 / (r_{11}(1 + \epsilon_1)^{-1})$$

# %% [markdown]
# By our useful lemma,
#
# $$\tilde{x}_1 = b_1 / (r_{11}(1 + \theta_1)) \Rightarrow (r_{11} + \theta_1 r_{11}) \tilde{x}_1 = b_1.$$

# %% [markdown]
# $$\frac{|\theta_1 r_{11}|}{|r_{11}|} = |\theta_1| \leq \gamma_1 = \epsilon_{\text{machine}} + O(\epsilon_{\text{machine}}^2).$$

# %% [markdown]
# ### $m = 2$
#
# The prevous case is now used in row 2,
#
# $$
# \tilde{x}_2 = b_2 / (r_{22}(1 + \theta_1))
# $$

# %% [markdown]
# The next step:
#
# $$\tilde{x}_1 = (b_{1} \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_2 \otimes r_{12})) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$

# %% [markdown]
# $$\tilde{x}_2 \otimes r_{12} = \tilde{x}_2 r_{12} (1 + \epsilon_2)$$

# %% [markdown]
# $$b_1 \bigcirc\!\!\!\!\!\!\!-\ \ \tilde{x}_2 r_{12}(1 + \epsilon_2) =
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3)$$

# %% [markdown]
# $$b_1 \bigcirc\!\!\!\!\!\!\!-\ \ \tilde{x}_2 r_{12}(1 + \epsilon_2) =
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3)$$

# %% [markdown]
# $$
# \begin{aligned}
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}
# &= \frac{(b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))}{r_{11}}(1 + \epsilon_3)(1 + \epsilon_4)\\ &=
# \frac{(b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))}{r_{11}(1 + \theta_2)}
# \end{aligned}$$

# %% [markdown]
# $$
# \begin{aligned}
# \Rightarrow r_{11}(1 + \theta_2)\tilde{x}_1 + r_{12}(1 + \epsilon_2)\tilde x_2 &= b_1 \\
# r_{22}(1 + \theta_1) \tilde{x}_2 &= b_2.
# \end{aligned}
# $$

# %% [markdown]
# $$
# [R \odot (I + \Theta_2)] \tilde x = b,
# $$
#
# - $\odot$ Hadamard (pointwise) product of matrices
# - $\Theta_k$ upper triangular $k \times k$ matrix whose entries are $\theta_k$

# %% [markdown]
# ### $m = 3, \dots$
#
# $$\tilde{x}_1 = (\cdots ((b_{1} \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_m \otimes r_{1m})) \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_{m-1} \otimes r_{1{m-1}})) \bigcirc\!\!\!\!\!\!\!-\ \ \cdots \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_2 \otimes r_{12})) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$
#
# (our `backsubstitution` does the updates in the opposite order of the book)

# %% [markdown]
# What we had in the top row of the $m=2$ case can generalize like
#
# $$
# \begin{aligned}
# \tilde{x}_1 &= \left([b_1 - \{r_{1,3:m}+r_{1,3:m} + \vec{\theta}_{m-2}\} \cdot\tilde{x}_{3:m}] (1 + \theta_{m-2}) \bigcirc\!\!\!\!\!\!\!-\ \ (r_2 (1 + \epsilon_1)) \cdot \tilde x_2\right) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}
# \\
# &= \frac{\left([b_1 - \{r_{1,3:m}+r_{1,3:m} + \vec{\theta}_{m-2}\} \cdot\tilde{x}_{3:m}] (1 + \theta_{m-2}) - (r_2 (1 + \epsilon_2)) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_2)}
# \end{aligned}
# $$
#
# where $\vec{\theta}_{m-2}$ is a vector with $\theta_{m-2}$ entries

# %% [markdown]
# we want to sneak that $(1 + \epsilon_1)$ term out so that it doesn't perturb $b_1$

# %% [markdown]
# Divide the top and the bottom by $(1 + \theta_{m-2})$, combining $(1 + \theta_{m-2})^{-1}(1 + \epsilon_2)$
# into $(1 + \theta_{m-1})$:
#
# $$
# \begin{aligned}
# \tilde{x}_1
# &= \frac{\left([b_1 - \{r_{1,3:m}+r_{1,3:m} + \vec{\theta}_{m-2}\} \cdot\tilde{x}_{3:m}] - (r_2 (1 + \theta_{m-1})) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_m)}
# \\
# &= \frac{\left(b_1 - \{r_{1,3:m}+r_{1,3:m} + \vec{\theta}_{m-2}\} \cdot\tilde{x}_{3:m} - (r_2 (1 + \theta_{m-1})) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_m)}
# \\
# &= \frac{\left(b_1 - \{r_{1,2:m}+r_{1,2:m} + \vec{\theta}_{m-1}\} \cdot\tilde{x}_{2:m}\right)}{r_{11}(1 + \theta_m)}
# \end{aligned}
# $$

# %% [markdown]
# This matches the inductive case and gives us the backward error form
#
# $$
# [R \odot (I + \Theta_m)] \tilde x = b,
# $$
